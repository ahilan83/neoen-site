# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df_pow = pd.read_pickle('/mnt/data-r6/ahilan/dataset/neoen/process/pow_inv-32-A_5min.pkl')
df_POA = pd.read_pickle('/mnt/data-r6/ahilan/dataset/neoen/process/poa_5min.pkl')
df_Tmod = pd.read_pickle('/mnt/data-r6/ahilan/dataset/neoen/process/tmod_5min.pkl')
df_met = pd.read_pickle('/mnt/data-r6/ahilan/dataset/neoen/process/met_5min.pkl')
df_T = df_met[['Temp','Timestamp']]
df_T = df_T.rename(columns={'Temp': 'Temp','Timestamp': 'time'})

df_inner = pd.merge(df_pow, df_POA, on='time', how='inner')
df_inner2 = pd.merge(df_inner, df_Tmod, on='time', how='inner')
df = pd.merge(df_inner2, df_T, on='time', how='inner')

df.set_index('time', inplace=True)
df = df.rename(columns={'power': 'Power','value_x': 'POA','value_y': 'Tmod' })

print(df.shape)
print(df.columns)
# Out:
# (113472, 4)
# Index(['Power', 'POA', 'Tmod', 'Temp'], dtype='object')

# %%
# Define the morning hour range
start_hour = 6
end_hour = 21
# Filter rows based on morning hour range
df = df[(df.index.hour >= start_hour) & (df.index.hour < end_hour)]
print(df.shape)
# Out:
# (70920, 4)

# %%
df = df[df['POA']>0]
df = df[df['Power']>0]
print(df.shape)
# Out:
# (34341, 4)

# %%
# Solar panel = JKM345M-72-V x 5742 panels
POA_std = 1000
Capacity = 5742*345/1000000
T_std = 25 
#T_std = df['Tmod'].mean()
alpha = -0.004

'''
start_date = '2023-11-20'
end_date = '2023-11-22'

test = (df['Power'][start_date:end_date])/(Capacity*(1 + alpha*(df['Tmod'][start_date:end_date] - T_std))*df['POA'][start_date:end_date]/POA_std)
print(test)
test.replace([np.inf, -np.inf], np.nan, inplace=True)
temp = test.dropna()
P_constant = np.mean(temp[temp>0])
P_constant = np.mean(temp)
print(P_constant)
'''


df['shifted_Power'] = df['Power'] 
df.loc['2023-04-02':'2023-09-30', 'shifted_Power'] = df.loc['2023-04-02':'2023-09-30', 'Power'].shift(periods=60, freq='T')


P_constant = 1.0
df['Power_calculated'] = P_constant*Capacity*(1 + alpha*(df['Tmod'] - T_std))*df['POA']/POA_std
df['Power_error'] = df['Power_calculated'] - df['shifted_Power']

# %%
# Define the period you want to plot
#start_date = '2023-04-01'
#end_date = '2023-04-03'

start_date = df.index.min()
end_date = df.index.max()


# Slice the DataFrame based on the specified period
df_period = df[start_date:end_date]
df_shifted_period = df_shifted[start_date:end_date]
df_period['Power_calculated'].resample('5min').mean().plot(figsize=(10, 3), color =['Red'],label='Calculated Power')
df_period['shifted_Power'][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Green'],label='Measured Power')
plt.ylabel('Power/ MW')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.show()

#ax = df_period['Power'].resample('5min').mean().plot(figsize=(10, 3))
#plt.ylabel('Measured Power/ MW')
#plt.xlabel('Date')
#plt.grid(True)
#plt.show()

#ax = df_period['Power_calculated'].resample('5min').mean().plot(figsize=(10, 3))
#plt.ylabel('Calculated Power/ MW')
#plt.xlabel('Date')
#plt.grid(True)
#plt.show()

ax = df_period['Power_error'].resample('5min').mean().plot(figsize=(10, 3))
plt.ylabel('Power Error/ MW')
plt.xlabel('Date')
plt.grid(True)
plt.show()

# %%
df.shape
# Out:
# (34341, 7)

# %%
df.describe()
# Out:
#               Power           POA          Tmod          Temp  shifted_Power  \
# count  3.434100e+04  34341.000000  34341.000000  34341.000000   3.217100e+04
# mean   6.970179e-01    495.334639     29.389750     21.325090   7.404436e-01
# std    5.623242e-01    366.921442     14.079137     41.200906   5.522680e-01
# min    1.819751e-11      0.488424     -6.118014      0.000000   1.819751e-11
# 25%    1.311146e-01    133.984600     19.136560     13.600000   1.939989e-01
# 50%    6.312100e-01    513.308900     28.813590     17.900000   7.129405e-01
# 75%    1.217491e+00    793.867900     39.763870     24.200000   1.246005e+00
# max    1.700452e+00   1502.591000     68.853870    655.260000   1.700452e+00
#
#        Power_calculated   Power_error
# count      34341.000000  32171.000000
# mean           0.931573      0.242090
# std            0.666763      0.413017
# min            0.000973     -1.418751
# 25%            0.269666      0.028878
# 50%            0.998488      0.150396
# 75%            1.491648      0.297443
# max            2.787336      2.518962

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, RepeatVector, TimeDistributed, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.losses import mse
from tensorflow.keras import backend as K
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint

# Example: Generate synthetic time series data (replace with your own data loading)
np.random.seed(42)

# Define the period you want to plot
start_date = df.index.min()
end_date = df.index.max()

temp = df[start_date:end_date][['Power','Power_error']].resample('5min').mean()
print(temp.isnull().any().any())
print(np.any(np.isinf(temp)))
print(temp.shape)
temp_cleaned = temp.dropna()
print(temp_cleaned.shape)
data = temp_cleaned.values
print(temp_cleaned.index)
# Out:
# True
# False
# (85687, 2)
# (32171, 2)
# DatetimeIndex(['2023-03-16 07:10:00', '2023-03-16 07:15:00',
#                '2023-03-16 07:20:00', '2023-03-16 07:25:00',
#                '2023-03-16 07:30:00', '2023-03-16 07:40:00',
#                '2023-03-16 07:45:00', '2023-03-16 07:50:00',
#                '2023-03-16 07:55:00', '2023-03-16 08:00:00',
#                ...
#                '2024-01-07 18:40:00', '2024-01-07 18:45:00',
#                '2024-01-07 18:50:00', '2024-01-07 18:55:00',
#                '2024-01-07 19:00:00', '2024-01-07 19:05:00',
#                '2024-01-07 19:10:00', '2024-01-07 19:15:00',
#                '2024-01-07 19:25:00', '2024-01-07 19:40:00'],
#               dtype='datetime64[ns]', name='time', length=32171, freq=None)

# %%
# Normalize data
#scaler = MinMaxScaler()
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data)

# %%
# Create sequences/windows
'''
timesteps = 5 # Length of each sequence/window
num_sequences = len(data_normalized) - timesteps + 1

# Initialize an array to hold the sequences
sequences = np.zeros((num_sequences, timesteps, 1))

for i in range(num_sequences):
    sequences[i] = data_normalized[i:i + timesteps].reshape(-1, 1)

# Print the shape of the resulting three-dimensional array
print("Shape of the sequences array:", sequences.shape)
'''


# Create sequences for LSTM
def create_sequences(data, timesteps):
    sequences = []
    for i in range(len(data) - timesteps):
        seq = data[i:i + timesteps]
        sequences.append(seq)
    return np.array(sequences)


# Train-test split
#X_train, X_test = train_test_split(sequences, test_size=0.2, random_state=42)

# Define the split ratio
train_ratio = 1.0
test_ratio = 0.0
num_train_samples = int(train_ratio * len(data_normalized))

# Split the data
train_data = data_normalized[:num_train_samples]
test_data = data_normalized[num_train_samples:]

train_data_date = temp_cleaned.index[:num_train_samples]
test_data_date = temp_cleaned.index[num_train_samples:]


timesteps = 30  # Example sequence leng|th
train_sequences = create_sequences(train_data, timesteps)
test_sequences = create_sequences(test_data, timesteps)

print("Shape of the train sequences array:", train_sequences.shape)
print("Shape of the test sequences array:", test_sequences.shape)
# Out:
# Shape of the train sequences array: (32141, 30, 2)
# Shape of the test sequences array: (0,)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Function to sample from the latent space
def sampling(args):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# Hyperparameters
input_dim = 1   
latent_dim = 20
dropout_rate = 0

# Encoder
inputs = Input(shape=(timesteps, input_dim))
h = LSTM(64, return_sequences=True,dropout=dropout_rate, recurrent_dropout=dropout_rate)(inputs)
h = LSTM(32)(h)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# Decoder
#decoder_h1 = Dense(64)
decoder_repeat = RepeatVector(timesteps)
decoder_h2 = LSTM(32, return_sequences=True)
decoder_lstm = LSTM(64, return_sequences=True, dropout=dropout_rate, recurrent_dropout=dropout_rate)
decoder_output = TimeDistributed(Dense(input_dim))

#z = decoder_h1(z)
h_decoded = decoder_repeat(z)
h_decoded = decoder_h2(h_decoded)
x_decoded_mean = decoder_lstm(h_decoded)
x_decoded_mean = decoder_output(x_decoded_mean)



# VAE model
vae = Model(inputs, x_decoded_mean)

# Loss function
reconstruction_loss = mse(K.flatten(inputs), K.flatten(x_decoded_mean))
reconstruction_loss *= timesteps * input_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + 0.15*kl_loss)
vae.add_loss(vae_loss)



checkpoint_callback = ModelCheckpoint(
    filepath='/home/ahilan/gen-research/neoen-site/models/test2model_checkpoint_{epoch:02d}.h5',  # Save with epoch and batch number in the filename
    save_weights_only=False,  # Set to True if you only want to save the model weights
    save_freq='epoch',  # Change this to 'batch' to save after every batch
    verbose=1  # Set to 1 for verbose logging, 0 for silent
)


# Compile model
optimizer = Adam(learning_rate=1e-3)
vae.compile(optimizer=optimizer)
vae.summary()


# Train the VAE with early stopping
history = vae.fit(train_sequences, epochs=200, batch_size=64, callbacks=[checkpoint_callback])


# Plot training & validation loss values
plt.plot(history.history['loss'])

plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train'], loc='upper right')
plt.show()


## Plot training & validation loss values
#plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
#plt.title('Model loss')
#plt.xlabel('Epoch')
#plt.ylabel('Loss')
#plt.legend(['Train', 'Validation'], loc='upper right')
#plt.show()
# Out:
# Model: "model_37"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_33 (InputLayer)       [(None, 30, 1)]              0         []
#
#  lstm_82 (LSTM)              (None, 30, 128)              66560     ['input_33[0][0]']
#
#  lstm_83 (LSTM)              (None, 64)                   49408     ['lstm_82[0][0]']
#
#  dense_130 (Dense)           (None, 20)                   1300      ['lstm_83[0][0]']
#
#  dense_131 (Dense)           (None, 20)                   1300      ['lstm_83[0][0]']
#
#  lambda_29 (Lambda)          (None, 20)                   0         ['dense_130[0][0]',
#                                                                      'dense_131[0][0]']
#
#  dense_132 (Dense)           (None, 64)                   1344      ['lambda_29[0][0]']
#
#  repeat_vector_29 (RepeatVe  (None, 30, 64)               0         ['dense_132[0][0]']
#  ctor)
#
#  lstm_84 (LSTM)              (None, 30, 64)               33024     ['repeat_vector_29[0][0]']
#
#  lstm_85 (LSTM)              (None, 30, 128)              98816     ['lstm_84[0][0]']
#
#  time_distributed_28 (TimeD  (None, 30, 1)                129       ['lstm_85[0][0]']
#  istributed)
#
#  tf.__operators__.add_54 (T  (None, 20)                   0         ['dense_131[0][0]']
#  FOpLambda)
#
#  tf.math.square_27 (TFOpLam  (None, 20)                   0         ['dense_130[0][0]']
#  bda)
#
#  tf.reshape_55 (TFOpLambda)  (None,)                      0         ['time_distributed_28[0][0]']
#
#  tf.reshape_54 (TFOpLambda)  (None,)                      0         ['input_33[0][0]']
#
#  tf.math.subtract_54 (TFOpL  (None, 20)                   0         ['tf.__operators__.add_54[0][0
#  ambda)                                                             ]',
#                                                                      'tf.math.square_27[0][0]']
#
#  tf.math.exp_27 (TFOpLambda  (None, 20)                   0         ['dense_131[0][0]']
#  )
#
#  tf.convert_to_tensor_27 (T  (None,)                      0         ['tf.reshape_55[0][0]']
#  FOpLambda)
#
#  tf.cast_27 (TFOpLambda)     (None,)                      0         ['tf.reshape_54[0][0]']
#
#  tf.math.subtract_55 (TFOpL  (None, 20)                   0         ['tf.math.subtract_54[0][0]',
#  ambda)                                                              'tf.math.exp_27[0][0]']
#
#  tf.math.squared_difference  (None,)                      0         ['tf.convert_to_tensor_27[0][0
#  _27 (TFOpLambda)                                                   ]',
#                                                                      'tf.cast_27[0][0]']
#
#  tf.math.reduce_sum_27 (TFO  (None,)                      0         ['tf.math.subtract_55[0][0]']
#  pLambda)
#
#  tf.math.reduce_mean_54 (TF  ()                           0         ['tf.math.squared_difference_2
#  OpLambda)                                                          7[0][0]']
#
#  tf.math.multiply_82 (TFOpL  (None,)                      0         ['tf.math.reduce_sum_27[0][0]'
#  ambda)                                                             ]
#
#  tf.math.multiply_81 (TFOpL  ()                           0         ['tf.math.reduce_mean_54[0][0]
#  ambda)                                                             ']
#
#  tf.math.multiply_83 (TFOpL  (None,)                      0         ['tf.math.multiply_82[0][0]']
#  ambda)
#
#  tf.__operators__.add_55 (T  (None,)                      0         ['tf.math.multiply_81[0][0]',
#  FOpLambda)                                                          'tf.math.multiply_83[0][0]']
#
#  tf.math.reduce_mean_55 (TF  ()                           0         ['tf.__operators__.add_55[0][0
#  OpLambda)                                                          ]']
#
#  add_loss_26 (AddLoss)       ()                           0         ['tf.math.reduce_mean_55[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 251881 (983.91 KB)
# Trainable params: 251881 (983.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 503/503 [==============================] - ETA: 0s - loss: 16.9005
# Epoch 1: saving model to model_checkpoint_01.h5
# 503/503 [==============================] - 92s 169ms/step - loss: 16.9005
# Epoch 2/200
# 503/503 [==============================] - ETA: 0s - loss: 14.0400
# Epoch 2: saving model to model_checkpoint_02.h5
# 503/503 [==============================] - 84s 167ms/step - loss: 14.0400
# Epoch 3/200
# 503/503 [==============================] - ETA: 0s - loss: 13.5574
# Epoch 3: saving model to model_checkpoint_03.h5
# 503/503 [==============================] - 84s 166ms/step - loss: 13.5574
# Epoch 4/200
# 503/503 [==============================] - ETA: 0s - loss: 13.3990
# Epoch 4: saving model to model_checkpoint_04.h5
# 503/503 [==============================] - 84s 167ms/step - loss: 13.3990
# Epoch 5/200
# 503/503 [==============================] - ETA: 0s - loss: 13.3013
# Epoch 5: saving model to model_checkpoint_05.h5
# 503/503 [==============================] - 84s 168ms/step - loss: 13.3013
# Epoch 6/200
# 503/503 [==============================] - ETA: 0s - loss: 13.1846
# Epoch 6: saving model to model_checkpoint_06.h5
# 503/503 [==============================] - 84s 167ms/step - loss: 13.1846
# Epoch 7/200
# 503/503 [==============================] - ETA: 0s - loss: 13.1323
# Epoch 7: saving model to model_checkpoint_07.h5
# 503/503 [==============================] - 84s 167ms/step - loss: 13.1323
# Epoch 8/200
# 503/503 [==============================] - ETA: 0s - loss: 13.0953
# Epoch 8: saving model to model_checkpoint_08.h5
# 503/503 [==============================] - 84s 167ms/step - loss: 13.0953
# Epoch 9/200
# 503/503 [==============================] - ETA: 0s - loss: 13.0610
# Epoch 9: saving model to model_checkpoint_09.h5
# 503/503 [==============================] - 85s 169ms/step - loss: 13.0610
# Epoch 10/200
# 503/503 [==============================] - ETA: 0s - loss: 12.9976
# Epoch 10: saving model to model_checkpoint_10.h5
# 503/503 [==============================] - 85s 169ms/step - loss: 12.9976
# Epoch 11/200
# 503/503 [==============================] - ETA: 0s - loss: 12.9923
# Epoch 11: saving model to model_checkpoint_11.h5
# 503/503 [==============================] - 85s 169ms/step - loss: 12.9923
# Epoch 12/200
# 503/503 [==============================] - ETA: 0s - loss: 12.8890
# Epoch 12: saving model to model_checkpoint_12.h5
# 503/503 [==============================] - 85s 169ms/step - loss: 12.8890
# Epoch 13/200
# 503/503 [==============================] - ETA: 0s - loss: 12.8834
# Epoch 13: saving model to model_checkpoint_13.h5
# 503/503 [==============================] - 85s 169ms/step - loss: 12.8834
# Epoch 14/200
# 503/503 [==============================] - ETA: 0s - loss: 12.7840
# Epoch 14: saving model to model_checkpoint_14.h5
# 503/503 [==============================] - 85s 168ms/step - loss: 12.7840
# Epoch 15/200
# 503/503 [==============================] - ETA: 0s - loss: 12.7556
# Epoch 15: saving model to model_checkpoint_15.h5
# 503/503 [==============================] - 84s 168ms/step - loss: 12.7556
# Epoch 16/200
# 503/503 [==============================] - ETA: 0s - loss: 12.7162
# Epoch 16: saving model to model_checkpoint_16.h5
# 503/503 [==============================] - 85s 169ms/step - loss: 12.7162
# Epoch 17/200
# 503/503 [==============================] - ETA: 0s - loss: 12.5915
# Epoch 17: saving model to model_checkpoint_17.h5
# 503/503 [==============================] - 84s 168ms/step - loss: 12.5915
# Epoch 18/200
# 503/503 [==============================] - ETA: 0s - loss: 12.5485
# Epoch 18: saving model to model_checkpoint_18.h5
# 503/503 [==============================] - 85s 169ms/step - loss: 12.5485
# Epoch 19/200
# 503/503 [==============================] - ETA: 0s - loss: 12.4670
# Epoch 19: saving model to model_checkpoint_19.h5
# 503/503 [==============================] - 85s 168ms/step - loss: 12.4670
# Epoch 20/200
# 503/503 [==============================] - ETA: 0s - loss: 12.3998
# Epoch 20: saving model to model_checkpoint_20.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 12.3998
# Epoch 21/200
# 503/503 [==============================] - ETA: 0s - loss: 12.3480
# Epoch 21: saving model to model_checkpoint_21.h5
# 503/503 [==============================] - 86s 171ms/step - loss: 12.3480
# Epoch 22/200
# 503/503 [==============================] - ETA: 0s - loss: 12.3532
# Epoch 22: saving model to model_checkpoint_22.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 12.3532
# Epoch 23/200
# 503/503 [==============================] - ETA: 0s - loss: 12.2591
# Epoch 23: saving model to model_checkpoint_23.h5
# 503/503 [==============================] - 85s 168ms/step - loss: 12.2591
# Epoch 24/200
# 503/503 [==============================] - ETA: 0s - loss: 12.2081
# Epoch 24: saving model to model_checkpoint_24.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 12.2081
# Epoch 25/200
# 503/503 [==============================] - ETA: 0s - loss: 12.2013
# Epoch 25: saving model to model_checkpoint_25.h5
# 503/503 [==============================] - 86s 171ms/step - loss: 12.2013
# Epoch 26/200
# 503/503 [==============================] - ETA: 0s - loss: 12.1837
# Epoch 26: saving model to model_checkpoint_26.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 12.1837
# Epoch 27/200
# 503/503 [==============================] - ETA: 0s - loss: 12.1953
# Epoch 27: saving model to model_checkpoint_27.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 12.1953
# Epoch 28/200
# 503/503 [==============================] - ETA: 0s - loss: 12.1552
# Epoch 28: saving model to model_checkpoint_28.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 12.1552
# Epoch 29/200
# 503/503 [==============================] - ETA: 0s - loss: 12.1504
# Epoch 29: saving model to model_checkpoint_29.h5
# 503/503 [==============================] - 86s 171ms/step - loss: 12.1504
# Epoch 30/200
# 503/503 [==============================] - ETA: 0s - loss: 12.0762
# Epoch 30: saving model to model_checkpoint_30.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 12.0762
# Epoch 31/200
# 503/503 [==============================] - ETA: 0s - loss: 12.1544
# Epoch 31: saving model to model_checkpoint_31.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 12.1544
# Epoch 32/200
# 503/503 [==============================] - ETA: 0s - loss: 12.1031
# Epoch 32: saving model to model_checkpoint_32.h5
# 503/503 [==============================] - 87s 174ms/step - loss: 12.1031
# Epoch 33/200
# 503/503 [==============================] - ETA: 0s - loss: 12.0421
# Epoch 33: saving model to model_checkpoint_33.h5
# 503/503 [==============================] - 87s 172ms/step - loss: 12.0421
# Epoch 34/200
# 503/503 [==============================] - ETA: 0s - loss: 11.9796
# Epoch 34: saving model to model_checkpoint_34.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.9796
# Epoch 35/200
# 503/503 [==============================] - ETA: 0s - loss: 11.9980
# Epoch 35: saving model to model_checkpoint_35.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.9980
# Epoch 36/200
# 503/503 [==============================] - ETA: 0s - loss: 11.9271
# Epoch 36: saving model to model_checkpoint_36.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.9271
# Epoch 37/200
# 503/503 [==============================] - ETA: 0s - loss: 12.0184
# Epoch 37: saving model to model_checkpoint_37.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 12.0184
# Epoch 38/200
# 503/503 [==============================] - ETA: 0s - loss: 11.9254
# Epoch 38: saving model to model_checkpoint_38.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.9254
# Epoch 39/200
# 503/503 [==============================] - ETA: 0s - loss: 11.9076
# Epoch 39: saving model to model_checkpoint_39.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.9076
# Epoch 40/200
# 503/503 [==============================] - ETA: 0s - loss: 11.8911
# Epoch 40: saving model to model_checkpoint_40.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.8911
# Epoch 41/200
# 503/503 [==============================] - ETA: 0s - loss: 11.8347
# Epoch 41: saving model to model_checkpoint_41.h5
# 503/503 [==============================] - 87s 172ms/step - loss: 11.8347
# Epoch 42/200
# 503/503 [==============================] - ETA: 0s - loss: 11.8945
# Epoch 42: saving model to model_checkpoint_42.h5
# 503/503 [==============================] - 87s 172ms/step - loss: 11.8945
# Epoch 43/200
# 503/503 [==============================] - ETA: 0s - loss: 11.9851
# Epoch 43: saving model to model_checkpoint_43.h5
# 503/503 [==============================] - 86s 171ms/step - loss: 11.9851
# Epoch 44/200
# 503/503 [==============================] - ETA: 0s - loss: 11.8576
# Epoch 44: saving model to model_checkpoint_44.h5
# 503/503 [==============================] - 87s 172ms/step - loss: 11.8576
# Epoch 45/200
# 503/503 [==============================] - ETA: 0s - loss: 11.8669
# Epoch 45: saving model to model_checkpoint_45.h5
# 503/503 [==============================] - 86s 171ms/step - loss: 11.8669
# Epoch 46/200
# 503/503 [==============================] - ETA: 0s - loss: 11.8259
# Epoch 46: saving model to model_checkpoint_46.h5
# 503/503 [==============================] - 87s 174ms/step - loss: 11.8259
# Epoch 47/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7515
# Epoch 47: saving model to model_checkpoint_47.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.7515
# Epoch 48/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7923
# Epoch 48: saving model to model_checkpoint_48.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.7923
# Epoch 49/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7110
# Epoch 49: saving model to model_checkpoint_49.h5
# 503/503 [==============================] - 86s 171ms/step - loss: 11.7110
# Epoch 50/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7350
# Epoch 50: saving model to model_checkpoint_50.h5
# 503/503 [==============================] - 86s 170ms/step - loss: 11.7350
# Epoch 51/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7647
# Epoch 51: saving model to model_checkpoint_51.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.7647
# Epoch 52/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7440
# Epoch 52: saving model to model_checkpoint_52.h5
# 503/503 [==============================] - 86s 171ms/step - loss: 11.7440
# Epoch 53/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7374
# Epoch 53: saving model to model_checkpoint_53.h5
# 503/503 [==============================] - 87s 172ms/step - loss: 11.7374
# Epoch 54/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7540
# Epoch 54: saving model to model_checkpoint_54.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.7540
# Epoch 55/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7346
# Epoch 55: saving model to model_checkpoint_55.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.7346
# Epoch 56/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6835
# Epoch 56: saving model to model_checkpoint_56.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.6835
# Epoch 57/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6405
# Epoch 57: saving model to model_checkpoint_57.h5
# 503/503 [==============================] - 87s 172ms/step - loss: 11.6405
# Epoch 58/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5720
# Epoch 58: saving model to model_checkpoint_58.h5
# 503/503 [==============================] - 87s 172ms/step - loss: 11.5720
# Epoch 59/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6854
# Epoch 59: saving model to model_checkpoint_59.h5
# 503/503 [==============================] - 87s 174ms/step - loss: 11.6854
# Epoch 60/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6308
# Epoch 60: saving model to model_checkpoint_60.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.6308
# Epoch 61/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5500
# Epoch 61: saving model to model_checkpoint_61.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.5500
# Epoch 62/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4962
# Epoch 62: saving model to model_checkpoint_62.h5
# 503/503 [==============================] - 90s 178ms/step - loss: 11.4962
# Epoch 63/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5287
# Epoch 63: saving model to model_checkpoint_63.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.5287
# Epoch 64/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7133
# Epoch 64: saving model to model_checkpoint_64.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.7133
# Epoch 65/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5060
# Epoch 65: saving model to model_checkpoint_65.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.5060
# Epoch 66/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4819
# Epoch 66: saving model to model_checkpoint_66.h5
# 503/503 [==============================] - 88s 174ms/step - loss: 11.4819
# Epoch 67/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6537
# Epoch 67: saving model to model_checkpoint_67.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 11.6537
# Epoch 68/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7889
# Epoch 68: saving model to model_checkpoint_68.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.7889
# Epoch 69/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4840
# Epoch 69: saving model to model_checkpoint_69.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.4840
# Epoch 70/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4096
# Epoch 70: saving model to model_checkpoint_70.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.4096
# Epoch 71/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5317
# Epoch 71: saving model to model_checkpoint_71.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.5317
# Epoch 72/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7269
# Epoch 72: saving model to model_checkpoint_72.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 11.7269
# Epoch 73/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6539
# Epoch 73: saving model to model_checkpoint_73.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.6539
# Epoch 74/200
# 503/503 [==============================] - ETA: 0s - loss: 11.8689
# Epoch 74: saving model to model_checkpoint_74.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.8689
# Epoch 75/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6270
# Epoch 75: saving model to model_checkpoint_75.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.6270
# Epoch 76/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4177
# Epoch 76: saving model to model_checkpoint_76.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.4177
# Epoch 77/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4219
# Epoch 77: saving model to model_checkpoint_77.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.4219
# Epoch 78/200
# 503/503 [==============================] - ETA: 0s - loss: 12.0557
# Epoch 78: saving model to model_checkpoint_78.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 12.0557
# Epoch 79/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5110
# Epoch 79: saving model to model_checkpoint_79.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.5110
# Epoch 80/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5301
# Epoch 80: saving model to model_checkpoint_80.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.5301
# Epoch 81/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4880
# Epoch 81: saving model to model_checkpoint_81.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.4880
# Epoch 82/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6474
# Epoch 82: saving model to model_checkpoint_82.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 11.6474
# Epoch 83/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3589
# Epoch 83: saving model to model_checkpoint_83.h5
# 503/503 [==============================] - 92s 182ms/step - loss: 11.3589
# Epoch 84/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3932
# Epoch 84: saving model to model_checkpoint_84.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 11.3932
# Epoch 85/200
# 503/503 [==============================] - ETA: 0s - loss: 11.7310
# Epoch 85: saving model to model_checkpoint_85.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.7310
# Epoch 86/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5793
# Epoch 86: saving model to model_checkpoint_86.h5
# 503/503 [==============================] - 90s 179ms/step - loss: 11.5793
# Epoch 87/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5985
# Epoch 87: saving model to model_checkpoint_87.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.5985
# Epoch 88/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3836
# Epoch 88: saving model to model_checkpoint_88.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.3836
# Epoch 89/200
# 503/503 [==============================] - ETA: 0s - loss: 11.2629
# Epoch 89: saving model to model_checkpoint_89.h5
# 503/503 [==============================] - 90s 179ms/step - loss: 11.2629
# Epoch 90/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5688
# Epoch 90: saving model to model_checkpoint_90.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.5688
# Epoch 91/200
# 503/503 [==============================] - ETA: 0s - loss: 11.2401
# Epoch 91: saving model to model_checkpoint_91.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.2401
# Epoch 92/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0578
# Epoch 92: saving model to model_checkpoint_92.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.0578
# Epoch 93/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3623
# Epoch 93: saving model to model_checkpoint_93.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.3623
# Epoch 94/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4879
# Epoch 94: saving model to model_checkpoint_94.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.4879
# Epoch 95/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3151
# Epoch 95: saving model to model_checkpoint_95.h5
# 503/503 [==============================] - 86s 171ms/step - loss: 11.3151
# Epoch 96/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1110
# Epoch 96: saving model to model_checkpoint_96.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.1110
# Epoch 97/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1107
# Epoch 97: saving model to model_checkpoint_97.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.1107
# Epoch 98/200
# 503/503 [==============================] - ETA: 0s - loss: 11.2334
# Epoch 98: saving model to model_checkpoint_98.h5
# 503/503 [==============================] - 87s 172ms/step - loss: 11.2334
# Epoch 99/200
# 503/503 [==============================] - ETA: 0s - loss: 11.6458
# Epoch 99: saving model to model_checkpoint_99.h5
# 503/503 [==============================] - 86s 172ms/step - loss: 11.6458
# Epoch 100/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3025
# Epoch 100: saving model to model_checkpoint_100.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.3025
# Epoch 101/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4915
# Epoch 101: saving model to model_checkpoint_101.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.4915
# Epoch 102/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4377
# Epoch 102: saving model to model_checkpoint_102.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 11.4377
# Epoch 103/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1854
# Epoch 103: saving model to model_checkpoint_103.h5
# 503/503 [==============================] - 92s 182ms/step - loss: 11.1854
# Epoch 104/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3388
# Epoch 104: saving model to model_checkpoint_104.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.3388
# Epoch 105/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0860
# Epoch 105: saving model to model_checkpoint_105.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.0860
# Epoch 106/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1263
# Epoch 106: saving model to model_checkpoint_106.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.1263
# Epoch 107/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0360
# Epoch 107: saving model to model_checkpoint_107.h5
# 503/503 [==============================] - 87s 173ms/step - loss: 11.0360
# Epoch 108/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1881
# Epoch 108: saving model to model_checkpoint_108.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.1881
# Epoch 109/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0994
# Epoch 109: saving model to model_checkpoint_109.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.0994
# Epoch 110/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0824
# Epoch 110: saving model to model_checkpoint_110.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.0824
# Epoch 111/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0529
# Epoch 111: saving model to model_checkpoint_111.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.0529
# Epoch 112/200
# 503/503 [==============================] - ETA: 0s - loss: 10.9808
# Epoch 112: saving model to model_checkpoint_112.h5
# 503/503 [==============================] - 88s 174ms/step - loss: 10.9808
# Epoch 113/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4092
# Epoch 113: saving model to model_checkpoint_113.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 11.4092
# Epoch 114/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1607
# Epoch 114: saving model to model_checkpoint_114.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.1607
# Epoch 115/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1849
# Epoch 115: saving model to model_checkpoint_115.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.1849
# Epoch 116/200
# 503/503 [==============================] - ETA: 0s - loss: 11.9470
# Epoch 116: saving model to model_checkpoint_116.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.9470
# Epoch 117/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3519
# Epoch 117: saving model to model_checkpoint_117.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.3519
# Epoch 118/200
# 503/503 [==============================] - ETA: 0s - loss: 11.2311
# Epoch 118: saving model to model_checkpoint_118.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.2311
# Epoch 119/200
# 503/503 [==============================] - ETA: 0s - loss: 11.2581
# Epoch 119: saving model to model_checkpoint_119.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 11.2581
# Epoch 120/200
# 503/503 [==============================] - ETA: 0s - loss: 10.8873
# Epoch 120: saving model to model_checkpoint_120.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.8873
# Epoch 121/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1022
# Epoch 121: saving model to model_checkpoint_121.h5
# 503/503 [==============================] - 87s 174ms/step - loss: 11.1022
# Epoch 122/200
# 503/503 [==============================] - ETA: 0s - loss: 10.8292
# Epoch 122: saving model to model_checkpoint_122.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 10.8292
# Epoch 123/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0863
# Epoch 123: saving model to model_checkpoint_123.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.0863
# Epoch 124/200
# 503/503 [==============================] - ETA: 0s - loss: 10.9023
# Epoch 124: saving model to model_checkpoint_124.h5
# 503/503 [==============================] - 91s 180ms/step - loss: 10.9023
# Epoch 125/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0688
# Epoch 125: saving model to model_checkpoint_125.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.0688
# Epoch 126/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0086
# Epoch 126: saving model to model_checkpoint_126.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.0086
# Epoch 127/200
# 503/503 [==============================] - ETA: 0s - loss: 10.7573
# Epoch 127: saving model to model_checkpoint_127.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.7573
# Epoch 128/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1396
# Epoch 128: saving model to model_checkpoint_128.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.1396
# Epoch 129/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0402
# Epoch 129: saving model to model_checkpoint_129.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.0402
# Epoch 130/200
# 503/503 [==============================] - ETA: 0s - loss: 10.8431
# Epoch 130: saving model to model_checkpoint_130.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 10.8431
# Epoch 131/200
# 503/503 [==============================] - ETA: 0s - loss: 10.9602
# Epoch 131: saving model to model_checkpoint_131.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.9602
# Epoch 132/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1181
# Epoch 132: saving model to model_checkpoint_132.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.1181
# Epoch 133/200
# 503/503 [==============================] - ETA: 0s - loss: 11.2008
# Epoch 133: saving model to model_checkpoint_133.h5
# 503/503 [==============================] - 90s 180ms/step - loss: 11.2008
# Epoch 134/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1373
# Epoch 134: saving model to model_checkpoint_134.h5
# 503/503 [==============================] - 90s 179ms/step - loss: 11.1373
# Epoch 135/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0048
# Epoch 135: saving model to model_checkpoint_135.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.0048
# Epoch 136/200
# 503/503 [==============================] - ETA: 0s - loss: 10.8470
# Epoch 136: saving model to model_checkpoint_136.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.8470
# Epoch 137/200
# 503/503 [==============================] - ETA: 0s - loss: 10.6536
# Epoch 137: saving model to model_checkpoint_137.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 10.6536
# Epoch 138/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0786
# Epoch 138: saving model to model_checkpoint_138.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.0786
# Epoch 139/200
# 503/503 [==============================] - ETA: 0s - loss: 10.8913
# Epoch 139: saving model to model_checkpoint_139.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.8913
# Epoch 140/200
# 503/503 [==============================] - ETA: 0s - loss: 10.7412
# Epoch 140: saving model to model_checkpoint_140.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 10.7412
# Epoch 141/200
# 503/503 [==============================] - ETA: 0s - loss: 10.6152
# Epoch 141: saving model to model_checkpoint_141.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.6152
# Epoch 142/200
# 503/503 [==============================] - ETA: 0s - loss: 11.4136
# Epoch 142: saving model to model_checkpoint_142.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.4136
# Epoch 143/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5960
# Epoch 143: saving model to model_checkpoint_143.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.5960
# Epoch 144/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5668
# Epoch 144: saving model to model_checkpoint_144.h5
# 503/503 [==============================] - 92s 182ms/step - loss: 11.5668
# Epoch 145/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1656
# Epoch 145: saving model to model_checkpoint_145.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 11.1656
# Epoch 146/200
# 503/503 [==============================] - ETA: 0s - loss: 10.6814
# Epoch 146: saving model to model_checkpoint_146.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.6814
# Epoch 147/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0727
# Epoch 147: saving model to model_checkpoint_147.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 11.0727
# Epoch 148/200
# 503/503 [==============================] - ETA: 0s - loss: 10.9441
# Epoch 148: saving model to model_checkpoint_148.h5
# 503/503 [==============================] - 90s 178ms/step - loss: 10.9441
# Epoch 149/200
# 503/503 [==============================] - ETA: 0s - loss: 10.7373
# Epoch 149: saving model to model_checkpoint_149.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.7373
# Epoch 150/200
# 503/503 [==============================] - ETA: 0s - loss: 10.8522
# Epoch 150: saving model to model_checkpoint_150.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.8522
# Epoch 151/200
# 503/503 [==============================] - ETA: 0s - loss: 10.9443
# Epoch 151: saving model to model_checkpoint_151.h5
# 503/503 [==============================] - 87s 174ms/step - loss: 10.9443
# Epoch 152/200
# 503/503 [==============================] - ETA: 0s - loss: 11.2651
# Epoch 152: saving model to model_checkpoint_152.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.2651
# Epoch 153/200
# 503/503 [==============================] - ETA: 0s - loss: 10.7987
# Epoch 153: saving model to model_checkpoint_153.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 10.7987
# Epoch 154/200
# 503/503 [==============================] - ETA: 0s - loss: 10.6871
# Epoch 154: saving model to model_checkpoint_154.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 10.6871
# Epoch 155/200
# 503/503 [==============================] - ETA: 0s - loss: 10.8232
# Epoch 155: saving model to model_checkpoint_155.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 10.8232
# Epoch 156/200
# 503/503 [==============================] - ETA: 0s - loss: 10.7813
# Epoch 156: saving model to model_checkpoint_156.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.7813
# Epoch 157/200
# 503/503 [==============================] - ETA: 0s - loss: 10.6445
# Epoch 157: saving model to model_checkpoint_157.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.6445
# Epoch 158/200
# 503/503 [==============================] - ETA: 0s - loss: 11.3493
# Epoch 158: saving model to model_checkpoint_158.h5
# 503/503 [==============================] - 92s 182ms/step - loss: 11.3493
# Epoch 159/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0366
# Epoch 159: saving model to model_checkpoint_159.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 11.0366
# Epoch 160/200
# 503/503 [==============================] - ETA: 0s - loss: 11.0154
# Epoch 160: saving model to model_checkpoint_160.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 11.0154
# Epoch 161/200
# 503/503 [==============================] - ETA: 0s - loss: 10.6445
# Epoch 161: saving model to model_checkpoint_161.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 10.6445
# Epoch 162/200
# 503/503 [==============================] - ETA: 0s - loss: 10.5877
# Epoch 162: saving model to model_checkpoint_162.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 10.5877
# Epoch 163/200
# 503/503 [==============================] - ETA: 0s - loss: 10.7433
# Epoch 163: saving model to model_checkpoint_163.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 10.7433
# Epoch 164/200
# 503/503 [==============================] - ETA: 0s - loss: 11.5612
# Epoch 164: saving model to model_checkpoint_164.h5
# 503/503 [==============================] - 89s 177ms/step - loss: 11.5612
# Epoch 165/200
# 503/503 [==============================] - ETA: 0s - loss: 11.2213
# Epoch 165: saving model to model_checkpoint_165.h5
# 503/503 [==============================] - 88s 174ms/step - loss: 11.2213
# Epoch 166/200
# 503/503 [==============================] - ETA: 0s - loss: 10.9737
# Epoch 166: saving model to model_checkpoint_166.h5
# 503/503 [==============================] - 89s 178ms/step - loss: 10.9737
# Epoch 167/200
# 503/503 [==============================] - ETA: 0s - loss: 10.7495
# Epoch 167: saving model to model_checkpoint_167.h5
# 503/503 [==============================] - 89s 176ms/step - loss: 10.7495
# Epoch 168/200
# 503/503 [==============================] - ETA: 0s - loss: 10.4864
# Epoch 168: saving model to model_checkpoint_168.h5
# 503/503 [==============================] - 88s 175ms/step - loss: 10.4864
# Epoch 169/200
# 503/503 [==============================] - ETA: 0s - loss: 10.6459
# Epoch 169: saving model to model_checkpoint_169.h5
# 503/503 [==============================] - 88s 176ms/step - loss: 10.6459
# Epoch 170/200
# 503/503 [==============================] - ETA: 0s - loss: 11.1935
# Epoch 170: saving model to model_checkpoint_170.h5
# 503/503 [==============================] - 90s 179ms/step - loss: 11.1935
# Epoch 171/200
# 450/503 [=========================>....] - ETA: 9s - loss: 10.9372

# %%
vae = tf.keras.models.load_model('/home/ahilan/gen-research/neoen-site/models/test/model_checkpoint_150.h5')

# %%
encoder = Model(inputs, z_mean)
encoded_data = encoder.predict(train_sequences[:,:,1])

from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=42)
tsne_result = tsne.fit_transform(encoded_data)

plt.scatter(tsne_result[:, 0], tsne_result[:, 1])
plt.title('t-SNE projection of 10-dimensional latent space')
plt.xlabel('t-SNE1')
plt.ylabel('t-SNE2')
plt.show()


## Encode and decode some data points
#encoder = Model(inputs, z_mean)
#encoded_data = encoder.predict(train_sequences)

# Display some of the encoded data
#plt.scatter(encoded_data[:, 0], encoded_data[:, 1])
#plt.xlabel("Dimension 1")
#plt.ylabel("Dimension 2")
#plt.title("Encoded Data")
#plt.show()
# Out:
# 1005/1005 [==============================] - 20s 17ms/step

# %%
from sklearn.cluster import KMeans
#np.random.seed(42)
n_clusters=4
kmeans = KMeans(n_clusters)
clusters = kmeans.fit_predict(encoded_data)

plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=clusters)
plt.xlabel('Latent Dimension 1')
plt.ylabel('Latent Dimension 2')
plt.title('Clustering in Latent Space')
plt.show()
# Out:
# /home/ahilan/kernels/default/.venv/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
reconstructed_sequences = vae.predict(train_sequences[:,:,1])
# Out:
# 1005/1005 [==============================] - 33s 33ms/step

# %%
array_b = np.zeros((32141, 30, 1))
reconstructed_sequences_temp = np.concatenate([reconstructed_sequences,array_b], axis=-1) 
reconstructed_sequences_temp[:,:,1] = train_sequences[:,:,1]

# %%
# Add cluster labels to the original sequences
clusters_temp = np.repeat(clusters[:, None, None], train_sequences.shape[1], axis=1)
original_sequences_with_clusters = np.concatenate([train_sequences, clusters_temp], axis=-1)
reconstructed_sequences_with_clusters = np.concatenate([reconstructed_sequences_temp, clusters_temp], axis=-1)


# Initialize an array to hold cluster IDs for the entire time series
cluster_ids = np.full(len(train_data), -1)

# Map each sequence's cluster ID back to the corresponding indices in the original time series
for i in range(len(train_sequences)):
    cluster_ids[i:i+timesteps] = clusters[i]

# Handle the overlapping indices by assigning the most frequent cluster ID
for i in range(timesteps):
    unique, counts = np.unique(cluster_ids[i:i+timesteps], return_counts=True)
    most_frequent_cluster = unique[np.argmax(counts)]
    cluster_ids[i:i+timesteps] = most_frequent_cluster

# Ensure the cluster_ids array has the same length as the original time series
cluster_ids = cluster_ids[:len(train_data)]

def plot_time_series_with_clusters(data, cluster_ids, n_clusters):
    plt.figure(figsize=(15, 8))
    for cluster_id in range(n_clusters):
        plt.plot(data[cluster_ids == cluster_id], label=f'Cluster {cluster_id}')
    plt.xlabel('Time')
    plt.ylabel('Normalized Value')
    plt.title('Time Series with Cluster IDs')
    plt.legend()
    plt.show()


# 1. Reshape sequences back to original form
original_shape = (len(train_data), 3)
reconstructed_shape = (len(train_data), 3)
reconstructed_original_data = np.zeros(original_shape)
reconstructed_vae_data = np.zeros(reconstructed_shape)

for i in range(len(train_sequences) - timesteps):
    reconstructed_original_data[i:i + timesteps] = sequences_with_clusters[i]
    reconstructed_vae_data[i:i + timesteps] = reconstructed_sequences[i]


reconstructed_original_data[:,0:2] = scaler.inverse_transform(reconstructed_original_data[:,0:2])
reconstructed_vae_data[:,0:2] = scaler.inverse_transform(reconstructed_vae_data[:,0:2])


df_orginal = pd.DataFrame(data = reconstructed_original_data, index = train_data_date, columns = ['Power','Power_error','Clusters'])
df_vae_output = pd.DataFrame(data = reconstructed_vae_data, index = train_data_date, columns = ['Power_error','Power','Clusters'])

print(df_orginal.shape)
print(df_vae_output.shape)

start_date = '2023-05-22'
end_date = '2023-05-25'

df_orginal['Power_error'][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Red'],label='Original power data')
plt.ylabel('Power/ MW')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.show()

df_orginal['Power_error'][df_orginal['Clusters']==0][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Red'])
df_orginal['Power_error'][df_orginal['Clusters']==1][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Black'])
df_orginal['Power_error'][df_orginal['Clusters']==2][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Green'])
df_orginal['Power_error'][df_orginal['Clusters']==3][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Blue'])
plt.ylabel('Power/ MW')
plt.xlabel('Date')
plt.grid(True)
plt.show()

print(df_vae_output)
df_vae_output['Power_error'][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Red'])
#df_vae_output['Power_error'][df_vae_output['Clusters']==1][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Black'])
#df_vae_output['Power_error'][df_vae_output['Clusters']==2][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Green'])
#df_vae_output['Power_error'][df_vae_output['Clusters']==3][start_date:end_date].resample('5min').mean().plot(figsize=(10, 3), color =['Blue'])
plt.ylabel('Power/ MW')
plt.xlabel('Date')
plt.grid(True)
plt.show()


'''
print(train_data.shape)
plot_time_series_with_clusters(train_data[:,], cluster_ids, n_clusters)
'''
# Out:
# [[[-0.52217692 -0.58381675  2.        ]
#   [-0.37838963 -0.57567294  2.        ]
#   [-0.39183998 -0.55950268  2.        ]
#   ...
#   [-0.07569901 -0.10711341  2.        ]
#   [-0.07012568 -0.09532784  2.        ]
#   [-0.07091035 -0.06198014  2.        ]]
#
#  [[-0.52600837 -0.57567294  2.        ]
#   [-0.40947053 -0.55950268  2.        ]
#   [-0.41155586 -0.5244891   2.        ]
#   ...
#   [-0.02220234 -0.09532784  2.        ]
#   [-0.01104589 -0.06198014  2.        ]
#   [ 0.00307555 -0.04121001  2.        ]]
#
#  [[-0.31243825 -0.55950268  2.        ]
#   [-0.29416454 -0.5244891   2.        ]
#   [-0.24550006 -0.47898673  2.        ]
#   ...
#   [-0.1317583  -0.06198014  2.        ]
#   [-0.11953634 -0.04121001  2.        ]
#   [-0.10538118 -0.03953245  2.        ]]
#
#  ...
#
#  [[-0.51415932 -0.2776903   2.        ]
#   [-0.55677468 -0.39498214  2.        ]
#   [-0.46748129 -0.09909942  2.        ]
#   ...
#   [-0.45489207 -0.56016874  2.        ]
#   [-0.3456715  -0.56075626  2.        ]
#   [-0.41314682 -0.56708098  2.        ]]
#
#  [[-0.51385725 -0.39498214  2.        ]
#   [-0.54742438 -0.09909942  2.        ]
#   [-0.46206227 -0.1952429   2.        ]
#   ...
#   [-0.38965228 -0.56075626  2.        ]
#   [-0.47258353 -0.56708098  2.        ]
#   [-0.5435909  -0.57149408  2.        ]]
#
#  [[-0.51576948 -0.09909942  2.        ]
#   [-0.54550773 -0.1952429   2.        ]
#   [-0.4859986  -0.28598974  2.        ]
#   ...
#   [-0.51345396 -0.56708098  2.        ]
#   [-0.5422492  -0.57149408  2.        ]
#   [-0.56936061 -0.5839004   2.        ]]]
# (32171, 3)
# (32171, 3)
# (32171, 3)
# (32171, 3)
#                      Power_error     Power  Clusters
# time
# 2023-03-16 07:10:00     0.480581  0.070022 -0.416620
# 2023-03-16 07:15:00     0.573764  0.138262 -0.251394
# 2023-03-16 07:20:00     0.270485 -0.083839 -0.789154
# 2023-03-16 07:25:00     0.473101  0.064544 -0.429884
# 2023-03-16 07:30:00     0.565890  0.132496 -0.265355
# ...                          ...       ...       ...
# 2024-01-07 19:05:00     0.715541  0.242090  0.000000
# 2024-01-07 19:10:00     0.715541  0.242090  0.000000
# 2024-01-07 19:15:00     0.715541  0.242090  0.000000
# 2024-01-07 19:25:00     0.715541  0.242090  0.000000
# 2024-01-07 19:40:00     0.715541  0.242090  0.000000
#
# [32171 rows x 3 columns]
# '\nprint(train_data.shape)\nplot_time_series_with_clusters(train_data[:,], cluster_ids, n_clusters)\n'

# %%
data = train_data
data_sequences = train_sequences
date_index = train_data_date

reconstructed_sequences = vae.predict(data_sequences)

# 1. Reshape sequences back to original form
original_shape = (len(data), 1)
reconstructed_original_data = np.zeros(original_shape)
reconstructed_vae_data = np.zeros(original_shape)

for i in range(len(data_sequences) - timesteps):
    reconstructed_original_data[i:i + timesteps] = data_sequences[i]
    reconstructed_vae_data[i:i + timesteps] = reconstructed_sequences[i]


X_test_original = scaler.inverse_transform(reconstructed_original_data)
X_test_vae = scaler.inverse_transform(reconstructed_vae_data)

df_orginal = pd.DataFrame(data = X_test_original, index = date_index, columns = ['Power_error'])
df_vae_output = pd.DataFrame(data = X_test_vae, index = date_index, columns = ['Power_error'])
# Out:
# 1005/1005 [==============================] - 64s 62ms/step

# %%
# Define the period you want to plot
start_date = '2023-05-22'
end_date = '2023-05-25'

# Slice the DataFrame based on the specified period
df_orginal_period = df_orginal[start_date:end_date]
df_vae_output_period = df_vae_output[start_date:end_date]


df_orginal_period['Power_error'].resample('5min').mean().plot(figsize=(10, 3), color =['Red'],label='Original power data')
df_vae_output_period['Power_error'].resample('5min').mean().plot(figsize=(10, 3),color =['Black'],label='VAE generated data')
plt.ylabel('Power/ MW')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.show()



'''
df_period['POA'].resample('H').mean().plot(figsize=(5, 4))
plt.ylabel('POA/ WM$^{-2}$')
plt.xlabel('Date')
plt.grid(True)
plt.show()

df_period['Power'].resample('H').mean().plot(figsize=(5, 4))
plt.ylabel('Power/ MW')
plt.xlabel('Date')
plt.grid(True)
plt.show()
'''
# Out:
# "\ndf_period['POA'].resample('H').mean().plot(figsize=(5, 4))\nplt.ylabel('POA/ WM$^{-2}$')\nplt.xlabel('Date')\nplt.grid(True)\nplt.show()\n\ndf_period['Power'].resample('H').mean().plot(figsize=(5, 4))\nplt.ylabel('Power/ MW')\nplt.xlabel('Date')\nplt.grid(True)\nplt.show()\n"

# %%
data = test_data
data_sequences = test_sequences
date_index = test_data_date

# Calculate reconstruction loss
reconstructed_sequences = vae.predict(data_sequences)
reconstruction_errors = np.mean(np.square(data_sequences - reconstructed_sequences), axis=(1, 2))

# Threshold for anomaly detection
threshold = np.mean(reconstruction_errors) + 3 * np.std(reconstruction_errors)
print(threshold)

anomalies = reconstruction_errors > threshold

# Mark anomalies in the original data
df_vae_output['Anomaly'] = 0
df_vae_output['Anomaly'][timesteps:] = anomalies
# Out:
# 443/443 [==============================] - 16s 36ms/step
# 0.04758400445804291
# /tmp/ipykernel_2500201/2442981538.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vae_output['Anomaly'][timesteps:] = anomalies

# %%
# Define the period you want to plot
start_date = '2024-01-01'
end_date = '2024-01-04'

# Slice the DataFrame based on the specified period
df_orginal_period = df_orginal[start_date:end_date]
df_vae_output_period = df_vae_output[start_date:end_date]

plt.figure(figsize=(15, 5))
plt.plot(df_orginal_period.index, df_orginal_period['Power'], label='Power')
plt.plot(df_vae_output_period.index, df_vae_output_period['Power'], label='Predicted Power')
plt.scatter(df_vae_output_period.index[df_vae_output_period['Anomaly'] == 1], df_orginal_period['Power'][df_vae_output['Anomaly'] == 1], color='black', label='Anomaly')
plt.legend()
plt.show()

# %%
reconstructed_sequences = vae.predict(X_train)
reconstruction_errors = np.mean(np.square(X_train - reconstructed_sequences), axis=(1, 2))

# Threshold for anomaly detection
threshold = np.mean(reconstruction_errors) + 2 * np.std(reconstruction_errors)

anomalies = reconstruction_errors > threshold

df['Anomaly'] = 0
df['Anomaly'][time_steps:] = anomalies


# Visualize anomalies
plt.figure(figsize=(14, 6))
plt.plot(reconstruction_errors, label='Reconstruction Error')
plt.axhline(y=threshold, color='r', linestyle='--', label='Threshold')
plt.legend()
plt.show()
# Out:
# 2216/2216 [==============================] - 72s 33ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 2
#       1 reconstructed_sequences = vae.predict(X_train)
# ----> 2 reconstruction_errors = np.mean(np.square(X_test - reconstructed_sequences), axis=(1, 2))
#       4 # Threshold for anomaly detection
#       5 threshold = np.mean(reconstruction_errors) + 2 * np.std(reconstruction_errors)
#
# NameError: name 'X_test' is not defined

# %%
# Encode and decode some data points
encoder = Model(inputs, z_mean)
encoded_data = encoder.predict(X_train)

# Display some of the encoded data
plt.scatter(encoded_data[:, 0], encoded_data[:, 1])
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.title("Encoded Data Scatter Plot")
plt.show()

plt.hist(encoded_data[:, 0], bins=100, alpha=0.7, label='Feature 1')
plt.hist(encoded_data[:, 1], bins=100, alpha=0.7, label='Feature 2')
plt.title("Encoded Data Histogram")
plt.show()

# Extract latent representations and reconstructed sequences
reconstructed_sequences = vae.predict(X_train)
# Out:
# 73/73 [==============================] - 1s 5ms/step
# 73/73 [==============================] - 2s 8ms/step

# %%
# Plot original vs. reconstructed time series
#(reconstructed_sequences * data_std) + data_mean

# 1. Reshape sequences back to original form
original_shape = (len(data_normalized), 1)
reconstructed_original_data = np.zeros(original_shape)
reconstructed_vae_data = np.zeros(original_shape)

for i in range(num_sequences):
    reconstructed_original_data[i:i + timesteps] = sequences[i]
    reconstructed_vae_data[i:i + timesteps] = reconstructed_sequences[i]


reconstructed_original_data_no_norm = (reconstructed_original_data * data_std) + data_mean
reconstructed_vae_data_no_norm = (reconstructed_vae_data * data_std) + data_mean

print(reconstructed_original_data_no_norm.shape)
print(reconstructed_vae_data_no_norm.shape)

temp_cleaned['original'] = reconstructed_original_data_no_norm
temp_cleaned['vae_constructed'] = reconstructed_vae_data_no_norm


# Plotting the decomposed components
plt.figure(figsize=(12, 8))

plt.subplot(211)
plt.plot(temp_cleaned['original'], label='Original WCPR')
plt.legend(loc='upper left')

plt.subplot(212)
plt.plot(temp_cleaned['vae_constructed'], label='VAE reconstructed')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# (2318, 1)
# (2318, 1)
